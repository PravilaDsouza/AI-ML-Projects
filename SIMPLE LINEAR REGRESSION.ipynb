# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('Salary_dataset.csv')
data
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# 21          21              7.2   98274.0
# 22          22              8.0  101303.0
# 23          23              8.3  113813.0
# 24          24              8.8  109432.0
# 25          25              9.1  105583.0
# 26          26              9.6  116970.0
# 27          27              9.7  112636.0
# 28          28             10.4  122392.0
# 29          29             10.6  121873.0

# %%
df=data.drop('Unnamed: 0',axis=1)
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=df.iloc[:,:-1].values
x
# Out:
# array([[ 1.2],
#        [ 1.4],
#        [ 1.6],
#        [ 2.1],
#        [ 2.3],
#        [ 3. ],
#        [ 3.1],
#        [ 3.3],
#        [ 3.3],
#        [ 3.8],
#        [ 4. ],
#        [ 4.1],
#        [ 4.1],
#        [ 4.2],
#        [ 4.6],
#        [ 5. ],
#        [ 5.2],
#        [ 5.4],
#        [ 6. ],
#        [ 6.1],
#        [ 6.9],
#        [ 7.2],
#        [ 8. ],
#        [ 8.3],
#        [ 8.8],
#        [ 9.1],
#        [ 9.6],
#        [ 9.7],
#        [10.4],
#        [10.6]])

# %%
y=df.iloc[:,1].values
y
# Out:
# array([ 39344.,  46206.,  37732.,  43526.,  39892.,  56643.,  60151.,
#         54446.,  64446.,  57190.,  63219.,  55795.,  56958.,  57082.,
#         61112.,  67939.,  66030.,  83089.,  81364.,  93941.,  91739.,
#         98274., 101303., 113813., 109432., 105583., 116970., 112636.,
#        122392., 121873.])

# %%
#split the dataset into training and testing set
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
x_train,x_test,y_train,y_test
# Out:
# (array([[ 8. ],
#         [ 3. ],
#         [ 5.2],
#         [ 3.3],
#         [ 4.6],
#         [ 8.3],
#         [ 6.9],
#         [ 1.4],
#         [10.6],
#         [ 3.1],
#         [ 2.3],
#         [ 6. ],
#         [ 6.1],
#         [ 3.8],
#         [ 3.3],
#         [ 9.1],
#         [ 2.1],
#         [ 1.2],
#         [ 7.2],
#         [ 5. ],
#         [ 4.1]]),
#  array([[ 1.6],
#         [10.4],
#         [ 4.2],
#         [ 4. ],
#         [ 9.6],
#         [ 8.8],
#         [ 9.7],
#         [ 4.1],
#         [ 5.4]]),
#  array([101303.,  56643.,  66030.,  64446.,  61112., 113813.,  91739.,
#          46206., 121873.,  60151.,  39892.,  81364.,  93941.,  57190.,
#          54446., 105583.,  43526.,  39344.,  98274.,  67939.,  56958.]),
#  array([ 37732., 122392.,  57082.,  63219., 116970., 109432., 112636.,
#          55795.,  83089.]))

# %%
#Fitting the Simple Linear Regression model to the training dataset  
from sklearn.linear_model import LinearRegression  
regressor= LinearRegression()  
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= regressor.predict(x_test)
y_pred=pd.DataFrame(y_pred,columns=['Predicted'])
y_pred
# Out:
#        Predicted
# 0   40818.783270
# 1  123189.082589
# 2   65155.462615
# 3   63283.410357
# 4  115700.873560
# 5  108212.664531
# 6  116636.899689
# 7   64219.436486
# 8   76387.776158

# %%
x_pred=regressor.predict(x_train)
x_pred
# Out:
# array([100724.45550213,  53923.14907116,  74515.72390079,  56731.22745702,
#         68899.56712907, 103532.53388799,  90428.16808731,  38946.73101325,
#        125061.13484623,  54859.17519978,  47370.96617082,  82003.93292974,
#         82939.95905836,  61411.35810011,  56731.22745702, 111020.74291694,
#         45498.91391358,  37074.67875601,  93236.24647317,  72643.67164355,
#         64219.43648597])

# %% [markdown]
# ### comparing predicted values with actual values

# %%
y_test
# Out:
# array([ 37732., 122392.,  57082.,  63219., 116970., 109432., 112636.,
#         55795.,  83089.])

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,x_pred)
plt.title('training')
plt.show()

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,x_pred)
plt.title('testing')
plt.show()
